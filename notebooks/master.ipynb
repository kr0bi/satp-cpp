# %% [markdown]
# # Master Notebook Index
#
# Ordine consigliato di esecuzione:
#
# 1. `results_normal.ipynb`
# 2. `results_streaming.ipynb`
# 3. `results_cross_mode.ipynb`
# 4. (opzionali) notebook specifici: `streaming_seed_21041998_n10000000_by_d.ipynb`, `hll_vs_hllpp_difference_n10000000.ipynb`
#
# Questo notebook e solo un indice rapido.

# %%
from pathlib import Path
nb_dir = Path('.').resolve()
if not (nb_dir / 'results_normal.ipynb').exists():
    nb_dir = nb_dir / 'notebooks'

print('Notebook directory:', nb_dir)
for name in [
    'results_normal.ipynb',
    'results_streaming.ipynb',
    'results_cross_mode.ipynb',
    'streaming_seed_21041998_n10000000_by_d.ipynb',
    'hll_vs_hllpp_difference_n10000000.ipynb',
]:
    p = nb_dir / name
    print(f'- {name}:', 'OK' if p.exists() else 'MISSING')
